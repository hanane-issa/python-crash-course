# %% [markdown]
# # Module 4b: Expanding dataframes
#
# **In this section you will learn how:**
# - to add new rows, columns and dataframes to an existing dataframe.
#
# There are different methods to grow your dataframes, depending on what you attach to them. Here we will explore ways to combine pandas rows, columns and entire dataframes.

# %%
import pandas as pd
import numpy as np

# %%
# load the dataframe from the previous section, method is further explained in module 4d
transposed_dict_df = pd.read_csv("transposed_dict_df-4b.csv", index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # load the dataframe from the previous section, method is further explained in module 4d
# ----> 2 transposed_dict_df = pd.read_csv("transposed_dict_df-4b.csv", index_col=0)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'transposed_dict_df-4b.csv'

# %% [markdown]
# ### Adding new rows and columns
#
# Let's say we want to change our mind and keep the participant IDs as a standalone column, but not as row labels.
# Adding a new column is very straightforward - it's like selecting a column by label and assigning values to it:

# %%
# make sure the number of entries in the new column matches the number of rows in the dataframe
transposed_dict_df["ID"] = transposed_dict_df.index
transposed_dict_df
# Out:
#                gender   age  height  weight  smoking  \
# participant1      NaN   NaN     NaN    70.9    False
# participant2     male  40.0    1.88    50.0     True
# participant3     male  18.0    1.65    73.0     True
# participant4   female  83.0    1.72    87.0    False
# participant5   female  55.0    1.68    50.0    False
# participant6      NaN   NaN     NaN    64.0     True
# participant7     male  21.0    1.90    92.9    False
# participant8      NaN   NaN     NaN    75.4    False
# participant9   female  32.0    1.66    90.7     True
# participant10    male  67.0    1.78    82.3    False
#
#                                                         diseases  \
# participant1                              ('Asthma', 'Diabetes')
# participant2                                                  ()
# participant3                                    ('Lung cancer',)
# participant4           ('Cardio vascular disease', 'Alzheimers')
# participant5                               ('Asthma', 'Anxiety')
# participant6                                       ('Diabetes',)
# participant7                          ('Asthma', 'Colon cancer')
# participant8                                                  ()
# participant9                                     ('Depression',)
# participant10  ('Anxiety', 'Diabetes', 'Cardio vascular disea...
#
#                           ID
# participant1    participant1
# participant2    participant2
# participant3    participant3
# participant4    participant4
# participant5    participant5
# participant6    participant6
# participant7    participant7
# participant8    participant8
# participant9    participant9
# participant10  participant10

# %% [markdown]
# Same analogy applies to appending rows:

# %%
transposed_dict_df.loc["participant11"] = ["female", 34, 1.55, 64, False, (), "participant11"]
transposed_dict_df
# Out:
#                gender   age  height  weight  smoking  \
# participant1      NaN   NaN     NaN    70.9    False
# participant2     male  40.0    1.88    50.0     True
# participant3     male  18.0    1.65    73.0     True
# participant4   female  83.0    1.72    87.0    False
# participant5   female  55.0    1.68    50.0    False
# participant6      NaN   NaN     NaN    64.0     True
# participant7     male  21.0    1.90    92.9    False
# participant8      NaN   NaN     NaN    75.4    False
# participant9   female  32.0    1.66    90.7     True
# participant10    male  67.0    1.78    82.3    False
# participant11  female  34.0    1.55    64.0    False
#
#                                                         diseases  \
# participant1                              ('Asthma', 'Diabetes')
# participant2                                                  ()
# participant3                                    ('Lung cancer',)
# participant4           ('Cardio vascular disease', 'Alzheimers')
# participant5                               ('Asthma', 'Anxiety')
# participant6                                       ('Diabetes',)
# participant7                          ('Asthma', 'Colon cancer')
# participant8                                                  ()
# participant9                                     ('Depression',)
# participant10  ('Anxiety', 'Diabetes', 'Cardio vascular disea...
# participant11                                                 ()
#
#                           ID
# participant1    participant1
# participant2    participant2
# participant3    participant3
# participant4    participant4
# participant5    participant5
# participant6    participant6
# participant7    participant7
# participant8    participant8
# participant9    participant9
# participant10  participant10
# participant11  participant11

# %% [markdown]
# Since we don't need participant information twice and it would be nice to keep 0-based indexing reference for the rows when visualising the dataframe, let's rename rows to numbers again:

# %%
n_rows = transposed_dict_df.shape[0]
transposed_dict_df.index = np.arange(0, n_rows)
transposed_dict_df
# Out:
#     gender   age  height  weight  smoking  \
# 0      NaN   NaN     NaN    70.9    False
# 1     male  40.0    1.88    50.0     True
# 2     male  18.0    1.65    73.0     True
# 3   female  83.0    1.72    87.0    False
# 4   female  55.0    1.68    50.0    False
# 5      NaN   NaN     NaN    64.0     True
# 6     male  21.0    1.90    92.9    False
# 7      NaN   NaN     NaN    75.4    False
# 8   female  32.0    1.66    90.7     True
# 9     male  67.0    1.78    82.3    False
# 10  female  34.0    1.55    64.0    False
#
#                                              diseases             ID
# 0                              ('Asthma', 'Diabetes')   participant1
# 1                                                  ()   participant2
# 2                                    ('Lung cancer',)   participant3
# 3           ('Cardio vascular disease', 'Alzheimers')   participant4
# 4                               ('Asthma', 'Anxiety')   participant5
# 5                                       ('Diabetes',)   participant6
# 6                          ('Asthma', 'Colon cancer')   participant7
# 7                                                  ()   participant8
# 8                                     ('Depression',)   participant9
# 9   ('Anxiety', 'Diabetes', 'Cardio vascular disea...  participant10
# 10                                                 ()  participant11

# %% [markdown]
# ### Rearranging columns
#
# Also visually it would be more consistent to keep the ID column next to the row index at the beginning. You can rearrange all the columns again by listing all of them, but this time in your desired order:

# %%
transposed_dict_df = transposed_dict_df[['ID', 'gender', 'age', 'height', 'weight', 'smoking', 'diseases']]
transposed_dict_df
# Out:
#                ID  gender   age  height  weight  smoking  \
# 0    participant1     NaN   NaN     NaN    70.9    False
# 1    participant2    male  40.0    1.88    50.0     True
# 2    participant3    male  18.0    1.65    73.0     True
# 3    participant4  female  83.0    1.72    87.0    False
# 4    participant5  female  55.0    1.68    50.0    False
# 5    participant6     NaN   NaN     NaN    64.0     True
# 6    participant7    male  21.0    1.90    92.9    False
# 7    participant8     NaN   NaN     NaN    75.4    False
# 8    participant9  female  32.0    1.66    90.7     True
# 9   participant10    male  67.0    1.78    82.3    False
# 10  participant11  female  34.0    1.55    64.0    False
#
#                                              diseases
# 0                              ('Asthma', 'Diabetes')
# 1                                                  ()
# 2                                    ('Lung cancer',)
# 3           ('Cardio vascular disease', 'Alzheimers')
# 4                               ('Asthma', 'Anxiety')
# 5                                       ('Diabetes',)
# 6                          ('Asthma', 'Colon cancer')
# 7                                                  ()
# 8                                     ('Depression',)
# 9   ('Anxiety', 'Diabetes', 'Cardio vascular disea...
# 10                                                 ()

# %% [markdown]
# ### Joining pandas dataframes
#
# What if you have another dictionary/pandas dataframe with more participant data and you would like to combine them with this table? Or you would like to append another row, but you cannot call `.loc` anymore because your rows don't have string labels anymore? Then consider `pd.concat()` or `dataframe.merge()` depending on your use case.
#
# #### Columns
# Let's create an example column-based additional dataset:

# %%
additional_col_df = {
       "exercise_frequency": ["low", "medium", "high", "medium", "low", "high", "medium", "low", "high", "medium", "low"], 
       "alcohol_consumption": [np.nan, 0, 5, 1, 3, 0, 4, 2, 1, 0, 2]}
additional_col_df = pd.DataFrame(additional_col_df)
additional_col_df
# Out:
#    exercise_frequency  alcohol_consumption
# 0                 low                  NaN
# 1              medium                  0.0
# 2                high                  5.0
# 3              medium                  1.0
# 4                 low                  3.0
# 5                high                  0.0
# 6              medium                  4.0
# 7                 low                  2.0
# 8                high                  1.0
# 9              medium                  0.0
# 10                low                  2.0

# %% [markdown]
# If you simply wish to concatenate two dataframes along the columns, you can just add them in a list to `pd.concat` and specify the column axis:

# %%
concatenated_df = pd.concat([transposed_dict_df, additional_col_df], axis=1)
concatenated_df
# Out:
#                ID  gender   age  height  weight  smoking  \
# 0    participant1     NaN   NaN     NaN    70.9    False
# 1    participant2    male  40.0    1.88    50.0     True
# 2    participant3    male  18.0    1.65    73.0     True
# 3    participant4  female  83.0    1.72    87.0    False
# 4    participant5  female  55.0    1.68    50.0    False
# 5    participant6     NaN   NaN     NaN    64.0     True
# 6    participant7    male  21.0    1.90    92.9    False
# 7    participant8     NaN   NaN     NaN    75.4    False
# 8    participant9  female  32.0    1.66    90.7     True
# 9   participant10    male  67.0    1.78    82.3    False
# 10  participant11  female  34.0    1.55    64.0    False
#
#                                              diseases exercise_frequency  \
# 0                              ('Asthma', 'Diabetes')                low
# 1                                                  ()             medium
# 2                                    ('Lung cancer',)               high
# 3           ('Cardio vascular disease', 'Alzheimers')             medium
# 4                               ('Asthma', 'Anxiety')                low
# 5                                       ('Diabetes',)               high
# 6                          ('Asthma', 'Colon cancer')             medium
# 7                                                  ()                low
# 8                                     ('Depression',)               high
# 9   ('Anxiety', 'Diabetes', 'Cardio vascular disea...             medium
# 10                                                 ()                low
#
#     alcohol_consumption
# 0                   NaN
# 1                   0.0
# 2                   5.0
# 3                   1.0
# 4                   3.0
# 5                   0.0
# 6                   4.0
# 7                   2.0
# 8                   1.0
# 9                   0.0
# 10                  2.0

# %% [markdown]
# What if your additional table included participant IDs in a different order to the first table and also a different name? That's when `transposed_dict_df.merge` comes in handy - it can match the rows according to the desired label. In contrast to `pd.concat`, this method can only be used for the column-aligned concatenation.

# %%
# adding IDs to the additional dataframe
additional_col_df["participant_name"] = ['participant6', 'participant1', 'participant2', 'participant3',
                                         'participant4', 'participant5', 'participant7', 'participant8', 
                                         'participant9', 'participant10', 'participant11']

# %%
additional_col_df
# Out:
#    exercise_frequency  alcohol_consumption participant_name
# 0                 low                  NaN     participant6
# 1              medium                  0.0     participant1
# 2                high                  5.0     participant2
# 3              medium                  1.0     participant3
# 4                 low                  3.0     participant4
# 5                high                  0.0     participant5
# 6              medium                  4.0     participant7
# 7                 low                  2.0     participant8
# 8                high                  1.0     participant9
# 9              medium                  0.0    participant10
# 10                low                  2.0    participant11

# %% [markdown]
# Argument `left_on` refers to the column label in `transposed_dict_df` that we want to match with the column in `additional_col_df` specified in `right_on`:

# %%
merged_df = transposed_dict_df.merge(additional_col_df, left_on="ID", right_on="participant_name")
merged_df
# Out:
#                ID  gender   age  height  weight  smoking  \
# 0    participant1     NaN   NaN     NaN    70.9    False
# 1    participant2    male  40.0    1.88    50.0     True
# 2    participant3    male  18.0    1.65    73.0     True
# 3    participant4  female  83.0    1.72    87.0    False
# 4    participant5  female  55.0    1.68    50.0    False
# 5    participant6     NaN   NaN     NaN    64.0     True
# 6    participant7    male  21.0    1.90    92.9    False
# 7    participant8     NaN   NaN     NaN    75.4    False
# 8    participant9  female  32.0    1.66    90.7     True
# 9   participant10    male  67.0    1.78    82.3    False
# 10  participant11  female  34.0    1.55    64.0    False
#
#                                              diseases exercise_frequency  \
# 0                              ('Asthma', 'Diabetes')             medium
# 1                                                  ()               high
# 2                                    ('Lung cancer',)             medium
# 3           ('Cardio vascular disease', 'Alzheimers')                low
# 4                               ('Asthma', 'Anxiety')               high
# 5                                       ('Diabetes',)                low
# 6                          ('Asthma', 'Colon cancer')             medium
# 7                                                  ()                low
# 8                                     ('Depression',)               high
# 9   ('Anxiety', 'Diabetes', 'Cardio vascular disea...             medium
# 10                                                 ()                low
#
#     alcohol_consumption participant_name
# 0                   0.0     participant1
# 1                   5.0     participant2
# 2                   1.0     participant3
# 3                   3.0     participant4
# 4                   0.0     participant5
# 5                   NaN     participant6
# 6                   4.0     participant7
# 7                   2.0     participant8
# 8                   1.0     participant9
# 9                   0.0    participant10
# 10                  2.0    participant11

# %% [markdown]
# Here is a visual summary of the differences between `pd.concat` and `dataframe.merge` for merging dataframes by columns:
#
# <img src="../_static/images/concat-vs-merge.png" alt="concat-vs-merge"/>

# %% [markdown]
# #### Rows
#
# Combining dataframes along the rows is very similar to `pd.concat`. Just specify the rows axis. It is also sometimes useful to include `ignore_index=True` to preserve continuous row numbering if you don't keep row labels.

# %%
# creating a row-based table for the example
additional_rows_df = {"ID": ["participant17", "participant13", "participant14"], "gender": ["male", "female", "male"], "age": [70, 45, 29], "height": [1.82,  1.60, 1.75], "weight": [78.5, 62.3, 88.0], "smoking": [False, True, False], "diseases": [("Anxiety",), ("Diabetes", "Hypertension"), ()]}
additional_rows_df = pd.DataFrame(additional_rows_df)
additional_rows_df
# Out:
#               ID  gender  age  height  weight  smoking  \
# 0  participant17    male   70    1.82    78.5    False
# 1  participant13  female   45    1.60    62.3     True
# 2  participant14    male   29    1.75    88.0    False
#
#                    diseases
# 0                (Anxiety,)
# 1  (Diabetes, Hypertension)
# 2                        ()

# %%
# ignore index to have continuous rows numbering
concatenated_df = pd.concat([transposed_dict_df, additional_rows_df], axis=0, ignore_index=True) 
concatenated_df
# Out:
#                ID  gender   age  height  weight  smoking  \
# 0    participant1     NaN   NaN     NaN    70.9    False
# 1    participant2    male  40.0    1.88    50.0     True
# 2    participant3    male  18.0    1.65    73.0     True
# 3    participant4  female  83.0    1.72    87.0    False
# 4    participant5  female  55.0    1.68    50.0    False
# 5    participant6     NaN   NaN     NaN    64.0     True
# 6    participant7    male  21.0    1.90    92.9    False
# 7    participant8     NaN   NaN     NaN    75.4    False
# 8    participant9  female  32.0    1.66    90.7     True
# 9   participant10    male  67.0    1.78    82.3    False
# 10  participant11  female  34.0    1.55    64.0    False
# 11  participant17    male  70.0    1.82    78.5    False
# 12  participant13  female  45.0    1.60    62.3     True
# 13  participant14    male  29.0    1.75    88.0    False
#
#                                              diseases
# 0                              ('Asthma', 'Diabetes')
# 1                                                  ()
# 2                                    ('Lung cancer',)
# 3           ('Cardio vascular disease', 'Alzheimers')
# 4                               ('Asthma', 'Anxiety')
# 5                                       ('Diabetes',)
# 6                          ('Asthma', 'Colon cancer')
# 7                                                  ()
# 8                                     ('Depression',)
# 9   ('Anxiety', 'Diabetes', 'Cardio vascular disea...
# 10                                                 ()
# 11                                         (Anxiety,)
# 12                           (Diabetes, Hypertension)
# 13                                                 ()

# %% [markdown]
# Save the dataframe to work on it in the next section. The method `.to_csv` will be explained in more detail in module 4d.

# %%
transposed_dict_df.to_csv("transposed_dict_df-4c.csv", index=False)

# %% [markdown]
# Here we covered the basics of merging the dataframes with `pd.concat` and `dafaframe.merge`. However they have many more functionalities, such as taking the union or intersection (`join="outer"`/`join="inner"`) of column/row labels in `pd.concat`, which you can learn more about [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html#concatenating-series-and-dataframe-together).
